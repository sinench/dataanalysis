# %%
# %load_ext autoreload
# %autoreload 2
from context import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fn = r"C:\Users\sinen\Documents\dataanalysis\data\interim\carcteristiques-2021.parquet"
df = pd.read_csv(fn, sep=";", decimal=',', parse_dates= [['an','mois','jour','hrmn']],infer_datetime_format=True)

# %%
df
# Out:
#             Num_Acc  jour  mois    an   hrmn  lumiere dep    com
# 0      202100000001    30    11  2021  07:32        2  30  30319  \
# 1      202100000002    25     9  2021  14:20        1  51  51544
# 2      202100000003    15     7  2021  07:55        1  85  85048
# 3      202100000004    27     3  2021  19:45        5  93  93005
# 4      202100000005    25     2  2021  07:20        5  76  76429
# ...             ...   ...   ...   ...    ...      ...  ..    ...
# 56513  202100056514     1     1  2021  06:10        3  33  33021
# 56514  202100056515     1     1  2021  10:20        1  38  38405
# 56515  202100056516     1     1  2021  18:00        3  26  26064
# 56516  202100056517     1     1  2021  10:55        1  33  33003
# 56517  202100056518     2     1  2021  18:00        3  78  78423
#
#        localisation  intersection  cond_atmosph  collision_type
# 0                 1             1             1               1  \
# ...

# %%
df.dtypes
# Out:
# Num_Acc      int64
# jour         int64
# mois         int64
# an           int64
# hrmn        object
# lum          int64
# dep         object
# com         object
# agg          int64
# int          int64
# atm          int64
# col          int64
# adr         object
# lat        float64
# long       float64
# dtype: object

# %%
df.loc[0]
# Out:
# Num_Acc    202100000001
# jour                 30
# mois                 11
# an                 2021
# hrmn              07:32
# lum                   2
# dep                  30
# com               30319
# agg                   1
# int                   1
# atm                   1
# col                   1
# adr              CD 981
# lat           44.038958
# long           4.348022
# Name: 0, dtype: object

# %%
df = df.rename(columns={"lum":"lumiere", "int":"intersection", "agg":"localisation", "atm":"cond_atmosph", "col":"collision_type"})

# %%
df.dtypes
# Out:
# Num_Acc             int64
# jour                int64
# mois                int64
# an                  int64
# hrmn               object
# lumiere             int64
# dep                object
# com                object
# localisation        int64
# intersection        int64
# cond_atmosph        int64
# collision_type      int64
# adr                object
# lat               float64
# long              float64
# dtype: object
